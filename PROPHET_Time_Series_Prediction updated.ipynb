# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#The-Prophet-Forecasting-Model" data-toc-modified-id="The-Prophet-Forecasting-Model-1">The Prophet Forecasting Model</a></span></li><li><span><a href="#Insertion-of-cleaned-dataset" data-toc-modified-id="Insertion-of-cleaned-dataset-2">Insertion of cleaned dataset</a></span></li><li><span><a href="#Splitting-between-train-and-test-set" data-toc-modified-id="Splitting-between-train-and-test-set-3">Splitting between train and test set</a></span></li></ul></div>

# %% [markdown]
# # The Prophet Forecasting Model
# We use a decomposable time series model with three main model components: trend, seasonality, and holidays. They are combined in the following equation:  y(t) = g(t) + s(t) + h(t) + εt
#
#
# g(t): piecewise linear or logistic growth curve for modelling non-periodic changes in time series
#
# s(t): periodic changes (e.g. weekly/yearly seasonality)
#
# h(t): effects of holidays (user provided) with irregular schedules
#
# εt: error term accounts for any unusual changes not accommodated by the model
#
# Using time as a regressor, Prophet is trying to fit several linear and non linear functions of time as components. Modeling seasonality as an additive component is the same approach taken by exponential smoothing in Holt-Winters technique . We are, in effect, framing the forecasting problem as a curve-fitting exercise rather than looking explicitly at the time based dependence of each observation within a time series.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb

# !pip install prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
from prophet import Prophet

plt.style.use('fivethirtyeight')
# Out:
# Requirement already satisfied: prophet in c:\users\jeffe\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: LunarCalendar>=0.0.9 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (0.0.9)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (1.1.0)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: holidays>=0.14.2 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (0.23)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (1.5.3)
# Requirement already satisfied: convertdate>=2.1.2 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\jeffe\anaconda3\lib\site-packages (from prophet) (2.8.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\users\jeffe\anaconda3\lib\site-packages (from convertdate>=2.1.2->prophet) (0.5.12)
# Requirement already satisfied: hijri-converter in c:\users\jeffe\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (2.2.4)
# Requirement already satisfied: korean-lunar-calendar in c:\users\jeffe\anaconda3\lib\site-packages (from holidays>=0.14.2->prophet) (0.3.1)
# Requirement already satisfied: ephem>=3.7.5.3 in c:\users\jeffe\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (4.1.4)
# Requirement already satisfied: pytz in c:\users\jeffe\anaconda3\lib\site-packages (from LunarCalendar>=0.0.9->prophet) (2022.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jeffe\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\jeffe\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jeffe\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)

# %% [markdown]
# # Insertion of cleaned dataset

# %%
df=pd.read_csv('temp_asia_clean.csv')

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty      Country  \
# 0  1990-01-01               1.558                          0.460  Afghanistan
# 1  1990-02-01               3.669                          0.244  Afghanistan
# 2  1990-03-01               8.402                          0.311  Afghanistan
# 3  1990-04-01              14.457                          0.231  Afghanistan
# 4  1990-05-01              22.442                          0.316  Afghanistan
#
#    Year
# 0  1990
# 1  1990
# 2  1990
# 3  1990
# 4  1990

# %% [markdown]
# **We decided to use China as an example**

# %%
china = df.loc[df['Country'] == 'China', ['dt','AverageTemperature']]
china.columns = ['Date','Temp']
china['Date'] = pd.to_datetime(china['Date'])
china.reset_index(drop=True, inplace=True)
china.set_index('Date', inplace=True)

china.head()
# Out:
#               Temp
# Date
# 1990-01-01  -7.151
# 1990-02-01  -3.761
# 1990-03-01   2.889
# 1990-04-01   7.676
# 1990-05-01  13.765

# %% [markdown]
# Lets take a look at the temperature variation in China in our range set (1990-2013)

# %%
plt.figure(figsize=(22,6))
sns.lineplot(x=china.index, y=china['Temp'])
plt.title('Temperature Variation in China from 1990 until 2013')
plt.show()

# %% [markdown]
# # Splitting between train and test set

# %%
num_train= round(len(china) * 0.75)
train= china.iloc[:num_train]
test= china.iloc[num_train:]

# %%
fig, ax= plt.subplots(figsize= (27, 7))
train.plot(
    ax= ax, 
    label= 'Training Set'
)
test.plot(
    ax= ax, 
    label= 'Test Set'
)

ax.set_title('China Temperature by Year')
ax.set_xlabel('')
ax.set_ylabel('Temperature')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %% [markdown]
# **Creating of prophet set to make use of the model**

# %%
def create_prophet_set(df): 
    return (df
        .reset_index()
        .rename(columns= {
            'Date': 'ds',
            'Temp': 'y'
        })
    )

train_prophet= create_prophet_set(train)
test_prophet= create_prophet_set(test)

# %%
model_prophet= Prophet()
model_prophet.fit(train_prophet)
# Out:
# 23:08:05 - cmdstanpy - INFO - Chain [1] start processing
# 23:08:05 - cmdstanpy - INFO - Chain [1] done processing

# %%
preds= model_prophet.predict(test_prophet)

# %%
fig, ax= plt.subplots(figsize= (15, 5))
model_prophet.plot(
    preds,
    ax= ax
)
ax.set_title('Prophet Forecast')
plt.show()

# %%
fig= model_prophet.plot_components(preds)
plt.show()

# %%
fig, ax= plt.subplots(figsize= (15, 5))
model_prophet.plot(preds, ax= ax)
ax.scatter(test_prophet['ds'], test_prophet['y'], color= 'red')
ax.set_title('Prophet Forecast vs Actual Value')
plt.show()

# %%
test_prophet['ds'].min()
# Out:
# Timestamp('2007-11-01 00:00:00')

# %%
fig, ax= plt.subplots(figsize= (15, 5))
model_prophet.plot(preds, ax= ax)
ax.scatter(test_prophet['ds'], test_prophet['y'], color= 'red')
ax.set_title('Prophet Forecast vs Actual Value')
ax.set_xbound(
    lower= test_prophet['ds'].min(),
    upper= test_prophet['ds'].max()
)
plt.show()

# %%
fig, ax= plt.subplots(figsize= (15, 8))

ax.scatter(test_prophet['ds'], test_prophet['y'], color= 'red', zorder= 5)
ax.legend()
model_prophet.plot(preds, ax= ax)

ax.legend()
ax.set_title('Prophet Prediction vs Actual Value', fontsize= 24)
ax.set_xbound(
    lower= pd.to_datetime('1990-01-01'),
    upper= pd.to_datetime('2013-01-01')
)
ax.set_ylabel('Temp in C')
ax.set_xlabel('Date')

plt.savefig('plot.png', dpi= 300, bbox_inches = "tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# It seems the forecasted outline is well fitted to the actual value of data present.
#
# Lastly would be to evaluate the model with the RMSE in the test set:

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """
        Calculates MAPE given y_true and y_pred
        Credit to Rob Mulla
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
rmse= np.sqrt(mean_squared_error(
    y_true= test_prophet['y'], y_pred= preds['yhat']
))
mae= mean_absolute_error(
    y_true= test_prophet['y'], y_pred= preds['yhat']
)
mape= mean_absolute_percentage_error(
    y_true= test_prophet['y'], y_pred= preds['yhat']
)

print(f'Root mean squared error: {round(rmse, 3)} degree Celsius.')
print(f'Mean absolute error: {round(mae, 3)} degree Celsius.')
print(f'Mean absolute percentage error: {round(mape, 3)}%')
# Out:
# Root mean squared error: 1.117 degree Celsius.
# Mean absolute error: 0.748 degree Celsius.
# Mean absolute percentage error: 25.977%
